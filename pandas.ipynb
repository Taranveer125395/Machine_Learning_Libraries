# %%
import pandas as pd
import numpy as np

# %%
arr = [1, 2, 3, 4, 5]
s = pd.Series(arr, dtype = int)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
arr = [1, 2, 3, 4, 5]
s1 = pd.Series(arr, index = ['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
info = {'BMW' : 2024,
        'Lamborghini' : 2023,
        'Ferrari' : 2002}
data = pd.Series(info)
data
# Out:
# BMW            2024
# Lamborghini    2023
# Ferrari        2002
# dtype: int64

# %%
data['BMW']
# Out:
# 2024

# %%
s*3
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# 4    15
# dtype: int32

# %%
data = {'Math' : 90,
        'Science' : 88,
        'English' : 95}

db = pd.Series(data)
db
# Out:
# Math       90
# Science    88
# English    95
# dtype: int64

# %%
db[db < 90]
# Out:
# Science    88
# dtype: int64

# %%
data1 = {'Name' : ['Aizen', 'Yamanoto', 'Ichigo'],
         'Age' : [25, 60, 25],
         'City' : ['Espada', 'Soul Soceity', 'Midworld']}
df0 = pd.DataFrame(data1)
df0
# Out:
#        Name  Age          City
# 0     Aizen   25        Espada
# 1  Yamanoto   60  Soul Soceity
# 2    Ichigo   25      Midworld

# %%
data = [['Alice', 25, 'New York'],
        ['Bob', 30, 'Los Angeles'],
        ['Charlie', 35, 'Chicago']]
df = pd.DataFrame(data,
                  columns = ['Name','Age','City'],
                  index = ['a','b','c'])
df
# Out:
#       Name  Age         City
# a    Alice   25     New York
# b      Bob   30  Los Angeles
# c  Charlie   35      Chicago

# %%
data = pd.read_csv('test.csv')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
data.shape
# Out:
# (233599, 11)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
data.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3
# 233594                 NaN                 NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
pd.isna(data['Gender'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 233594    False
# 233595    False
# 233596    False
# 233597    False
# 233598    False
# Name: Gender, Length: 233599, dtype: bool

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
data['Product_Category_2'].notna()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 233594    False
# 233595     True
# 233596     True
# 233597     True
# 233598     True
# Name: Product_Category_2, Length: 233599, dtype: bool

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
data.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
data['Gender'].value_counts()
# Out:
# Gender
# M    175772
# F     57827
# Name: count, dtype: int64

# %%
data['Marital_Status'].value_counts()
# Out:
# Marital_Status
# 0    137807
# 1     95792
# Name: count, dtype: int64

# %%
data2 = pd.read_excel('Sales_Data_Analysis.xlsx')
data2
# Out:
#           Date   Product Name         Category  Sales Quantity  Unit Price  \
# 0   2024-04-24     Smartphone      Electronics               3      369.55
# 1   2024-01-16        Fiction            Books               2      113.23
# 2   2024-04-11        Science            Books               9      212.66
# 3   2024-03-22           Doll             Toys               7      173.42
# 4   2024-02-17          Jeans         Clothing               7       52.87
# ..         ...            ...              ...             ...         ...
# 195 2024-12-07         Tablet      Electronics               5       27.48
# 196 2024-04-14           Doll             Toys               5      472.94
# 197 2024-03-02         Jacket         Clothing               1      251.21
# 198 2024-09-29  Action Figure             Toys               4      252.63
# 199 2024-08-11      Microwave  Home Appliances               1      232.58
#
#      Total Sales Region Salesperson
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            200 non-null    datetime64[ns]
#  1   Product Name    200 non-null    object
#  2   Category        200 non-null    object
#  3   Sales Quantity  200 non-null    int64
#  4   Unit Price      200 non-null    float64
#  5   Total Sales     200 non-null    float64
#  6   Region          200 non-null    object
#  7   Salesperson     200 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 12.6+ KB

# %%
data2.shape
# Out:
# (200, 8)

# %%
data2.describe()
# Out:
#                       Date  Sales Quantity  Unit Price  Total Sales
# count                  200      200.000000  200.000000   200.000000
# mean   2024-06-26 02:31:12        5.425000  250.086600  1330.496550
# min    2024-01-02 00:00:00        1.000000    6.610000     6.760000
# 25%    2024-03-21 18:00:00        3.000000  134.705000   430.050000
# 50%    2024-06-20 12:00:00        5.000000  251.455000  1096.905000
# 75%    2024-10-05 12:00:00        8.000000  373.150000  1897.425000
# max    2024-12-27 00:00:00       10.000000  498.080000  4980.800000
# std                    NaN        2.827428  141.439554  1114.824533

# %%
data2.isnull().sum()
# Out:
# Date              0
# Product Name      0
# Category          0
# Sales Quantity    0
# Unit Price        0
# Total Sales       0
# Region            0
# Salesperson       0
# dtype: int64

# %%
data2.isna()
# Out:
#       Date  Product Name  Category  Sales Quantity  Unit Price  Total Sales  \
# 0    False         False     False           False       False        False
# 1    False         False     False           False       False        False
# 2    False         False     False           False       False        False
# 3    False         False     False           False       False        False
# 4    False         False     False           False       False        False
# ..     ...           ...       ...             ...         ...          ...
# 195  False         False     False           False       False        False
# 196  False         False     False           False       False        False
# 197  False         False     False           False       False        False
# 198  False         False     False           False       False        False
# 199  False         False     False           False       False        False
#
#      Region  Salesperson
# 0     False        False
# ...

# %%
data2.head()
# Out:
#         Date Product Name     Category  Sales Quantity  Unit Price  \
# 0 2024-04-24   Smartphone  Electronics               3      369.55
# 1 2024-01-16      Fiction        Books               2      113.23
# 2 2024-04-11      Science        Books               9      212.66
# 3 2024-03-22         Doll         Toys               7      173.42
# 4 2024-02-17        Jeans     Clothing               7       52.87
#
#    Total Sales Region Salesperson
# 0      1108.65   East         Bob
# 1       226.46   West       Alice
# 2      1913.94  North     Eleanor
# 3      1213.94   East       Alice
# 4       370.09   East       Alice

# %%
data2.tail()
# Out:
#           Date   Product Name         Category  Sales Quantity  Unit Price  \
# 195 2024-12-07         Tablet      Electronics               5       27.48
# 196 2024-04-14           Doll             Toys               5      472.94
# 197 2024-03-02         Jacket         Clothing               1      251.21
# 198 2024-09-29  Action Figure             Toys               4      252.63
# 199 2024-08-11      Microwave  Home Appliances               1      232.58
#
#      Total Sales Region Salesperson
# 195       137.40   West     Eleanor
# 196      2364.70  North       Alice
# 197       251.21   East   Catherine
# 198      1010.52  South       David
# 199       232.58   West       Alice

# %%
data2.columns
# Out:
# Index(['Date', 'Product Name', 'Category', 'Sales Quantity', 'Unit Price',
#        'Total Sales', 'Region', 'Salesperson'],
#       dtype='object')

# %%
data2.dtypes
# Out:
# Date              datetime64[ns]
# Product Name              object
# Category                  object
# Sales Quantity             int64
# Unit Price               float64
# Total Sales              float64
# Region                    object
# Salesperson               object
# dtype: object

# %%
data2['Region'].value_counts()
# Out:
# Region
# East     57
# North    56
# West     50
# South    37
# Name: count, dtype: int64

# %%
data2[['Region', 'Salesperson', 'Total Sales']]
# Out:
#     Region Salesperson  Total Sales
# 0     East         Bob      1108.65
# 1     West       Alice       226.46
# 2    North     Eleanor      1913.94
# 3     East       Alice      1213.94
# 4     East       Alice       370.09
# ..     ...         ...          ...
# 195   West     Eleanor       137.40
# 196  North       Alice      2364.70
# 197   East   Catherine       251.21
# 198  South       David      1010.52
# 199   West       Alice       232.58
#
# [200 rows x 3 columns]

# %%
data2.loc[5, 'Category']
# Out:
# 'Home Appliances'

# %%
data2.columns
# Out:
# Index(['Date', 'Product Name', 'Category', 'Sales Quantity', 'Unit Price',
#        'Total Sales', 'Region', 'Salesperson'],
#       dtype='object')

# %%
data2.loc[3]
# Out:
# Date              2024-03-22 00:00:00
# Product Name                     Doll
# Category                         Toys
# Sales Quantity                      7
# Unit Price                     173.42
# Total Sales                   1213.94
# Region                           East
# Salesperson                     Alice
# Name: 3, dtype: object

# %%
data2.loc[[0, 2], ['Product Name', 'Sales Quantity']]
# Out:
#   Product Name  Sales Quantity
# 0   Smartphone               3
# 2      Science               9

# %%
data2.iloc[1, 4]
# Out:
# 113.23

# %%
data2.loc[1, 'Unit Price']
# Out:
# 113.23

# %%
max_salary = data2['Total Sales'].max()
max_salary
# Out:
# 4980.8

# %%
max_salary2 = data2[data2['Total Sales'] == max_salary]
max_salary2
# Out:
#          Date Product Name  Category  Sales Quantity  Unit Price  Total Sales  \
# 15 2024-07-14        Shoes  Clothing              10      498.08       4980.8
#
#    Region Salesperson
# 15  North       David

# %%
specific_rows = data2[data2['Unit Price'] < 250]
specific_rows
# Out:
#           Date     Product Name         Category  Sales Quantity  Unit Price  \
# 1   2024-01-16          Fiction            Books               2      113.23
# 2   2024-04-11          Science            Books               9      212.66
# 3   2024-03-22             Doll             Toys               7      173.42
# 4   2024-02-17            Jeans         Clothing               7       52.87
# 5   2024-08-23  Air Conditioner  Home Appliances               9       66.79
# ..         ...              ...              ...             ...         ...
# 191 2024-08-20      Non-fiction            Books               6       82.92
# 193 2024-12-04       Smartphone      Electronics               7      245.40
# 194 2024-09-19       Board Game             Toys               2      175.86
# 195 2024-12-07           Tablet      Electronics               5       27.48
# 199 2024-08-11        Microwave  Home Appliances               1      232.58
#
#      Total Sales Region Salesperson
# ...

# %%
s2 = data2.query("Region == 'West'")
s2
# Out:
#           Date     Product Name         Category  Sales Quantity  Unit Price  \
# 1   2024-01-16          Fiction            Books               2      113.23
# 8   2024-03-24           Puzzle             Toys               6      180.86
# 12  2024-11-25     Refrigerator  Home Appliances               8       75.72
# 14  2024-01-25            Jeans         Clothing               2       80.66
# 23  2024-10-03           Jacket         Clothing               4      357.91
# 24  2024-08-19           Puzzle             Toys               2      127.71
# 28  2024-08-30            Dress         Clothing               7       99.25
# 31  2024-08-04            Dress         Clothing               3      142.88
# 32  2024-02-20          T-shirt         Clothing               1      327.81
# 39  2024-10-18           Laptop      Electronics               4      291.56
# 63  2024-10-10           Puzzle             Toys               3       99.96
# ...
