# %%
import pandas as pd
import numpy as np

# %%
arr = [1,2,3,4,5]
s = pd.Series(arr, dtype = int)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('Sales_Data_Analysis.xlsx')
df
# Out:
#           Date   Product Name         Category  Sales Quantity  Unit Price  \
# 0   2024-04-24     Smartphone      Electronics               3      369.55
# 1   2024-01-16        Fiction            Books               2      113.23
# 2   2024-04-11        Science            Books               9      212.66
# 3   2024-03-22           Doll             Toys               7      173.42
# 4   2024-02-17          Jeans         Clothing               7       52.87
# ..         ...            ...              ...             ...         ...
# 195 2024-12-07         Tablet      Electronics               5       27.48
# 196 2024-04-14           Doll             Toys               5      472.94
# 197 2024-03-02         Jacket         Clothing               1      251.21
# 198 2024-09-29  Action Figure             Toys               4      252.63
# 199 2024-08-11      Microwave  Home Appliances               1      232.58
#
#      Total Sales Region Salesperson
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            200 non-null    datetime64[ns]
#  1   Product Name    200 non-null    object
#  2   Category        200 non-null    object
#  3   Sales Quantity  200 non-null    int64
#  4   Unit Price      200 non-null    float64
#  5   Total Sales     200 non-null    float64
#  6   Region          200 non-null    object
#  7   Salesperson     200 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 12.6+ KB

# %%
df.shape
# Out:
# (200, 8)

# %%
df.describe()
# Out:
#                       Date  Sales Quantity  Unit Price  Total Sales
# count                  200      200.000000  200.000000   200.000000
# mean   2024-06-26 02:31:12        5.425000  250.086600  1330.496550
# min    2024-01-02 00:00:00        1.000000    6.610000     6.760000
# 25%    2024-03-21 18:00:00        3.000000  134.705000   430.050000
# 50%    2024-06-20 12:00:00        5.000000  251.455000  1096.905000
# 75%    2024-10-05 12:00:00        8.000000  373.150000  1897.425000
# max    2024-12-27 00:00:00       10.000000  498.080000  4980.800000
# std                    NaN        2.827428  141.439554  1114.824533

# %%
df.isnull().count()
# Out:
# Date              200
# Product Name      200
# Category          200
# Sales Quantity    200
# Unit Price        200
# Total Sales       200
# Region            200
# Salesperson       200
# dtype: int64

# %%
df.isna()
# Out:
#       Date  Product Name  Category  Sales Quantity  Unit Price  Total Sales  \
# 0    False         False     False           False       False        False
# 1    False         False     False           False       False        False
# 2    False         False     False           False       False        False
# 3    False         False     False           False       False        False
# 4    False         False     False           False       False        False
# ..     ...           ...       ...             ...         ...          ...
# 195  False         False     False           False       False        False
# 196  False         False     False           False       False        False
# 197  False         False     False           False       False        False
# 198  False         False     False           False       False        False
# 199  False         False     False           False       False        False
#
#      Region  Salesperson
# 0     False        False
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# Product Name      0
# Category          0
# Sales Quantity    0
# Unit Price        0
# Total Sales       0
# Region            0
# Salesperson       0
# dtype: int64

# %%
df.head()
# Out:
#         Date Product Name     Category  Sales Quantity  Unit Price  \
# 0 2024-04-24   Smartphone  Electronics               3      369.55
# 1 2024-01-16      Fiction        Books               2      113.23
# 2 2024-04-11      Science        Books               9      212.66
# 3 2024-03-22         Doll         Toys               7      173.42
# 4 2024-02-17        Jeans     Clothing               7       52.87
#
#    Total Sales Region Salesperson
# 0      1108.65   East         Bob
# 1       226.46   West       Alice
# 2      1913.94  North     Eleanor
# 3      1213.94   East       Alice
# 4       370.09   East       Alice

# %%
df.tail()
# Out:
#           Date   Product Name         Category  Sales Quantity  Unit Price  \
# 195 2024-12-07         Tablet      Electronics               5       27.48
# 196 2024-04-14           Doll             Toys               5      472.94
# 197 2024-03-02         Jacket         Clothing               1      251.21
# 198 2024-09-29  Action Figure             Toys               4      252.63
# 199 2024-08-11      Microwave  Home Appliances               1      232.58
#
#      Total Sales Region Salesperson
# 195       137.40   West     Eleanor
# 196      2364.70  North       Alice
# 197       251.21   East   Catherine
# 198      1010.52  South       David
# 199       232.58   West       Alice

# %%
df.columns
# Out:
# Index(['Date', 'Product Name', 'Category', 'Sales Quantity', 'Unit Price',
#        'Total Sales', 'Region', 'Salesperson'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Product Name              object
# Category                  object
# Sales Quantity             int64
# Unit Price               float64
# Total Sales              float64
# Region                    object
# Salesperson               object
# dtype: object

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of           Date   Product Name         Category  Sales Quantity  Unit Price  \
# 0   2024-04-24     Smartphone      Electronics               3      369.55
# 1   2024-01-16        Fiction            Books               2      113.23
# 2   2024-04-11        Science            Books               9      212.66
# 3   2024-03-22           Doll             Toys               7      173.42
# 4   2024-02-17          Jeans         Clothing               7       52.87
# ..         ...            ...              ...             ...         ...
# 195 2024-12-07         Tablet      Electronics               5       27.48
# 196 2024-04-14           Doll             Toys               5      472.94
# 197 2024-03-02         Jacket         Clothing               1      251.21
# 198 2024-09-29  Action Figure             Toys               4      252.63
# 199 2024-08-11      Microwave  Home Appliances               1      232.58
#
# ...

# %%
df.value_counts()
# Out:
# Date        Product Name  Category     Sales Quantity  Unit Price  Total Sales  Region  Salesperson
# 2024-01-02  Jacket        Clothing     5               429.91      2149.55      South   Eleanor        1
# 2024-08-31  Doll          Toys         8               390.12      3120.96      North   Alice          1
# 2024-08-19  Puzzle        Toys         2               127.71      255.42       West    Eleanor        1
# 2024-08-20  Non-fiction   Books        6               82.92       497.52       West    David          1
# 2024-08-21  Headphones    Electronics  1               362.61      362.61       North   Eleanor        1
#                                                                                                       ..
# 2024-04-23  Headphones    Electronics  4               409.21      1636.84      North   David          1
# 2024-04-24  Lego Set      Toys         2               391.71      783.42       North   Catherine      1
# ...

# %%
df['Region'].value_counts()
# Out:
# Region
# East     57
# North    56
# West     50
# South    37
# Name: count, dtype: int64

# %%
df['Total Sales'].value_counts()
# Out:
# Total Sales
# 1108.65    1
# 1372.77    1
# 548.76     1
# 486.71     1
# 278.36     1
#           ..
# 1748.04    1
# 368.24     1
# 461.90     1
# 1946.16    1
# 232.58     1
# Name: count, Length: 200, dtype: int64

# %%
df[['Region', 'Salesperson', 'Total Sales']]
# Out:
#     Region Salesperson  Total Sales
# 0     East         Bob      1108.65
# 1     West       Alice       226.46
# 2    North     Eleanor      1913.94
# 3     East       Alice      1213.94
# 4     East       Alice       370.09
# ..     ...         ...          ...
# 195   West     Eleanor       137.40
# 196  North       Alice      2364.70
# 197   East   Catherine       251.21
# 198  South       David      1010.52
# 199   West       Alice       232.58
#
# [200 rows x 3 columns]

# %%
df.loc['Salesperson']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df.loc['Salesperson']
#
# File c:\Users\dell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\dell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File c:\Users\dell\anaconda3\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...
